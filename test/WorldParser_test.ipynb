# %% [markdown]
# Codice per testare la trasformazione del file des in un grafo

# %%
import sys
sys.path.append('..')
from WorldParser import WorldParser


des_file = """
MAZE: "mylevel", ' '
FLAGS:premapped
GEOMETRY:center,center

MAP
|||||||||||||
|...........|
|..|........|
|...........|
|.......|...|
|.....|.....|
|...|....|..|
|||||||||||||
ENDMAP

BRANCH:(1,1,1,1),(0,0,0,0)
GOLD:1,(1,2)
GOLD:1,(2,1)
GOLD:1,(7,4)
GOLD:1,(9,4)
GOLD:1,(11,5)
GOLD:1,(6,1)

"""

# %%
parser = WorldParser(des_file)
gold_positions = parser.extract_gold_positions()
world_graph = parser.extract_world_graph()

print(gold_positions)
parser.plot_world_graph(world_graph, gold_positions)
# Out:
# [(2, 1), (1, 2), (4, 7), (4, 9), (5, 11), (1, 6)]
